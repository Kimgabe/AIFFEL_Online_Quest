# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras import models, layers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import utils

# %%
# 문제 3-1: cifar10 데이터셋을 로드하고, 훈련 데이터셋에서 20%를 검증 데이터셋으로 분리합니다.
# cifar10 데이터셋 로드
(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()

# 훈련 데이터셋과 검증 데이터셋 분리
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size=0.2)

# 훈련, 검증, 테스트 데이터와 레이블 종류가 몇개인지 출력합니다.
print("전체 학습 데이터: {} 레이블: {}".format(x_train_full.shape, y_train_full.shape))
print("학습 데이터: {} 레이블: {}".format(x_train.shape, y_train.shape))
print("검증 데이터: {} 레이블: {}".format(x_val.shape, y_val.shape))
print("테스트 데이터: {} 레이블: {}".format(x_test.shape, y_test.shape))
# Out:
# 전체 학습 데이터: (50000, 32, 32, 3) 레이블: (50000, 1)
# 학습 데이터: (40000, 32, 32, 3) 레이블: (40000, 1)
# 검증 데이터: (10000, 32, 32, 3) 레이블: (10000, 1)
# 테스트 데이터: (10000, 32, 32, 3) 레이블: (10000, 1)

# %%
# cifar10의 분류에 해당하는 'airplane', 'automobile', 'bird', 'cat', 'deer', 
# 'dog', 'frog', 'horse', 'ship', 'truck'를 class_name으로 정의합니다.
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# 훈련 데이터의 0번째인 x_train[0]를 이미지로 시각화합니다.
plt.style.use('seaborn-white')

plt.figure()
plt.imshow(x_train[0])
plt.colorbar()
plt.show()

# %%
# 훈련, 검증, 테스트 데이터의 형태(shape)을 출력합니다.
print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# (40000, 32, 32, 3)
# (10000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
# 문제 3-2: 훈련, 검증, 테스트 데이터의 형태(shape)을 32 * 32 * 3 = 3072로 변형합니다.
x_train = x_train.reshape((x_train.shape[0], 32 * 32 * 3))
x_val = x_val.reshape((x_val.shape[0], 32 * 32 * 3))
x_test = x_test.reshape((x_test.shape[0], 32 * 32 * 3))

print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# (40000, 3072)
# (10000, 3072)
# (10000, 3072)

# %%
# 훈련, 검증, 테스트 데이터를 255로 나누어 0~1 사이의 값으로 변환합니다.
x_train = x_train / 255.
x_val = x_val / 255.
x_test = x_test / 255.

# %%
# 문제 3-3: BatchNormalization과 Dropout을 적용하여 빠른 학습과 과대적합을 방지하고,
# 10개의 이미지를 분류하는 딥러닝 모델을 구성합니다.
model = models.Sequential()

model.add(layers.Input(shape=(32 * 32 * 3, )))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(10, activation='softmax'))

# %%
model.summary()

# 모델 컴파일
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo (None, 3072)              12288
# _________________________________________________________________
# dropout (Dropout)            (None, 3072)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                196672
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 209,866
# Trainable params: 203,594
# Non-trainable params: 6,272
# _________________________________________________________________

# %%
utils.plot_model(model, show_shapes=True)

# %%
# 문제 3-4: ModelCheckpoint와 EarlyStopping 콜백 함수를 적용하여 모델 학습을 진행합니다.
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# ModelCheckpoint 콜백 함수 정의
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True, verbose=1)

# EarlyStopping 콜백 함수 정의
early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1)

# 모델 학습
history = model.fit(x_train, y_train, epochs=20, batch_size=32,
                    validation_data=(x_val, y_val),
                    callbacks=[checkpoint, early_stopping])
# Out:
# Epoch 1/20
# 1250/1250 [==============================] - 6s 3ms/step - loss: 2.0645 - accuracy: 0.2939 - val_loss: 1.6868 - val_accuracy: 0.4056
#
# Epoch 00001: val_loss improved from inf to 1.68680, saving model to best_model.h5
# Epoch 2/20
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.8086 - accuracy: 0.3549 - val_loss: 1.6398 - val_accuracy: 0.4291
#
# Epoch 00002: val_loss improved from 1.68680 to 1.63979, saving model to best_model.h5
# Epoch 3/20
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.7637 - accuracy: 0.3730 - val_loss: 1.6047 - val_accuracy: 0.4332
#
# Epoch 00003: val_loss improved from 1.63979 to 1.60467, saving model to best_model.h5
# Epoch 4/20
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.7402 - accuracy: 0.3801 - val_loss: 1.5800 - val_accuracy: 0.4482
#
# Epoch 00004: val_loss improved from 1.60467 to 1.58001, saving model to best_model.h5
# Epoch 5/20
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.7278 - accuracy: 0.3861 - val_loss: 1.5700 - val_accuracy: 0.4507
#
# Epoch 00005: val_loss improved from 1.58001 to 1.56995, saving model to best_model.h5
# Epoch 6/20
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.7168 - accuracy: 0.3881 - val_loss: 1.5583 - val_accuracy: 0.4544
#
# Epoch 00006: val_loss improved from 1.56995 to 1.55834, saving model to best_model.h5
# Epoch 7/20
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.7088 - accuracy: 0.3938 - val_loss: 1.5442 - val_accuracy: 0.4623
#
# Epoch 00007: val_loss improved from 1.55834 to 1.54416, saving model to best_model.h5
# Epoch 8/20
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.6992 - accuracy: 0.3970 - val_loss: 1.5315 - val_accuracy: 0.4656
#
# Epoch 00008: val_loss improved from 1.54416 to 1.53147, saving model to best_model.h5
# Epoch 9/20
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.6930 - accuracy: 0.3975 - val_loss: 1.5341 - val_accuracy: 0.4642
#
# Epoch 00009: val_loss did not improve from 1.53147
# Epoch 10/20
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.6884 - accuracy: 0.3992 - val_loss: 1.5220 - val_accuracy: 0.4652
#
# Epoch 00010: val_loss improved from 1.53147 to 1.52201, saving model to best_model.h5
# Epoch 11/20
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.6895 - accuracy: 0.3981 - val_loss: 1.5182 - val_accuracy: 0.4708
#
# Epoch 00011: val_loss improved from 1.52201 to 1.51820, saving model to best_model.h5
# Epoch 12/20
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.6828 - accuracy: 0.4040 - val_loss: 1.5161 - val_accuracy: 0.4704
#
# Epoch 00012: val_loss improved from 1.51820 to 1.51612, saving model to best_model.h5
# Epoch 13/20
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.6775 - accuracy: 0.4056 - val_loss: 1.5085 - val_accuracy: 0.4743
#
# Epoch 00013: val_loss improved from 1.51612 to 1.50848, saving model to best_model.h5
# Epoch 14/20
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.6736 - accuracy: 0.4070 - val_loss: 1.5076 - val_accuracy: 0.4744
#
# Epoch 00014: val_loss improved from 1.50848 to 1.50756, saving model to best_model.h5
# Epoch 15/20
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.6727 - accuracy: 0.4042 - val_loss: 1.5068 - val_accuracy: 0.4758
#
# Epoch 00015: val_loss improved from 1.50756 to 1.50676, saving model to best_model.h5
# Epoch 16/20
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.6699 - accuracy: 0.4076 - val_loss: 1.4982 - val_accuracy: 0.4856
#
# Epoch 00016: val_loss improved from 1.50676 to 1.49824, saving model to best_model.h5
# Epoch 17/20
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.6668 - accuracy: 0.4067 - val_loss: 1.4989 - val_accuracy: 0.4811
#
# Epoch 00017: val_loss did not improve from 1.49824
# Epoch 18/20
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.6640 - accuracy: 0.4090 - val_loss: 1.4943 - val_accuracy: 0.4776
#
# Epoch 00018: val_loss improved from 1.49824 to 1.49433, saving model to best_model.h5
# Epoch 19/20
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.6564 - accuracy: 0.4137 - val_loss: 1.4928 - val_accuracy: 0.4807
#
# Epoch 00019: val_loss improved from 1.49433 to 1.49281, saving model to best_model.h5
# Epoch 20/20
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.6606 - accuracy: 0.4109 - val_loss: 1.4949 - val_accuracy: 0.4824
#
# Epoch 00020: val_loss did not improve from 1.49281

# %%
# 문제 3-5: 학습 히스토리의 `loss`, `val_loss`, `accuracy`, `val_accuracy`를 차트로 시각화합니다.
# 학습 히스토리 시각화
plt.style.use('seaborn-white')
plt.figure(figsize=(12, 4))

# Loss 차트
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy 차트
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# 테스트 데이터셋을 이용해 모델을 평가합니다.
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.4959 - accuracy: 0.4871
# [1.4958531856536865, 0.4871000051498413]
