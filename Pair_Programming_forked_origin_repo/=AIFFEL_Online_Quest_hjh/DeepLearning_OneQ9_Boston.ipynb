# %% [markdown]
# <a href="https://colab.research.google.com/github/hjhan1201/AIFFEL_Online_Quest/blob/main/DeepLearning_OneQ9_Boston.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Boston Housing 데이터셋을 이용해 주택 가격을 예측하는 딥러닝 모델을 실습합니다.

# %%
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# keras.datasets 안에 boston_housing 데이터셋을 로드합니다.
from keras.datasets import boston_housing

(train_data, train_labels), (test_data, test_labels) = boston_housing.load_data()

# 데이터셋의 크기를 확인합니다.
print(len(train_data))
print(len(test_data))
# Out:
# 404
# 102

# %%
# 문제 1-1: 데이터셋의 전처리를 위해 표준화 작업을 수행합니다.
# 먼저 입력 데이터의 각 특성의 평균을 뺍니다.
mean = train_data.mean(axis =0)
train_data = train_data - mean

# 평균을 뺀 입력 데이터에서 표준편차를 나눕니다.
# 데이터 특성의 중앙이 0에 가깝게 만들고, 표준편차가 1이 되게 만듭니다.
std = train_data.std(axis = 0)
train_data = train_data / std

# 테스트 데이터셋도 마찬가지로 평균을 빼고, 표준편차로 나눕니다.
test_data = test_data - mean
test_data = test_data / std

# %%
# 문제 1-2: 주택 가격 예측을 위한 딥러닝 모델 구성 및 컴파일합니다.
# input_shape은 (train_data.shape[1], )으로 구성합니다.
# 회귀(예측)을 위한 모델이므로 loss를 mse, metrics를 mae로 사용합니다.


def build_model():
    model = models.Sequential()
    model.add(layers.Dense(64, activation='relu', input_shape=(train_data.shape[1],)))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(1))
    model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
    return model

# %%
history = model.fit(train_data, train_labels,
                    epochs=100,
                    batch_size=8,
                    validation_data=(test_data, test_labels))
# Out:
# Epoch 1/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.7827 - mae: 0.6309 - val_loss: 16.4503 - val_mae: 2.6388
# Epoch 2/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.7926 - mae: 0.5970 - val_loss: 15.9799 - val_mae: 2.5762
# Epoch 3/100
# 51/51 [==============================] - 0s 6ms/step - loss: 0.7428 - mae: 0.6294 - val_loss: 16.0417 - val_mae: 2.6431
# Epoch 4/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.7241 - mae: 0.5988 - val_loss: 15.1029 - val_mae: 2.5199
# Epoch 5/100
# 51/51 [==============================] - 0s 6ms/step - loss: 0.7699 - mae: 0.6440 - val_loss: 16.2351 - val_mae: 2.6050
# Epoch 6/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.8148 - mae: 0.6308 - val_loss: 14.9067 - val_mae: 2.4910
# Epoch 7/100
# 51/51 [==============================] - 0s 6ms/step - loss: 0.8378 - mae: 0.6422 - val_loss: 16.2049 - val_mae: 2.5926
# Epoch 8/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.7268 - mae: 0.5979 - val_loss: 15.2621 - val_mae: 2.5826
# Epoch 9/100
# 51/51 [==============================] - 0s 6ms/step - loss: 0.8330 - mae: 0.6493 - val_loss: 16.0304 - val_mae: 2.6069
# Epoch 10/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.7623 - mae: 0.6174 - val_loss: 16.7997 - val_mae: 2.7250
# Epoch 11/100
# 51/51 [==============================] - 0s 6ms/step - loss: 0.7130 - mae: 0.6098 - val_loss: 16.8220 - val_mae: 2.8141
# Epoch 12/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.7587 - mae: 0.6161 - val_loss: 15.7197 - val_mae: 2.5970
# Epoch 13/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.8590 - mae: 0.6593 - val_loss: 14.9995 - val_mae: 2.4627
# Epoch 14/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6800 - mae: 0.5916 - val_loss: 16.1756 - val_mae: 2.6421
# Epoch 15/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.7758 - mae: 0.6118 - val_loss: 15.8639 - val_mae: 2.5927
# Epoch 16/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6248 - mae: 0.5651 - val_loss: 16.4497 - val_mae: 2.7517
# Epoch 17/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.8123 - mae: 0.6230 - val_loss: 16.2023 - val_mae: 2.7261
# Epoch 18/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.7036 - mae: 0.6057 - val_loss: 16.0095 - val_mae: 2.5021
# Epoch 19/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6378 - mae: 0.5629 - val_loss: 14.9455 - val_mae: 2.4974
# Epoch 20/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.8037 - mae: 0.6623 - val_loss: 15.7889 - val_mae: 2.5988
# Epoch 21/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.7047 - mae: 0.6124 - val_loss: 15.5535 - val_mae: 2.5605
# Epoch 22/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.8020 - mae: 0.6331 - val_loss: 15.8616 - val_mae: 2.5836
# Epoch 23/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.7506 - mae: 0.6117 - val_loss: 15.7033 - val_mae: 2.5272
# Epoch 24/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6612 - mae: 0.5702 - val_loss: 16.2996 - val_mae: 2.6259
# Epoch 25/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.7214 - mae: 0.5957 - val_loss: 16.4255 - val_mae: 2.5989
# Epoch 26/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.6602 - mae: 0.5958 - val_loss: 18.4822 - val_mae: 2.8986
# Epoch 27/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.7722 - mae: 0.6174 - val_loss: 17.1396 - val_mae: 2.6746
# Epoch 28/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.6817 - mae: 0.5947 - val_loss: 15.7392 - val_mae: 2.5374
# Epoch 29/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6964 - mae: 0.5796 - val_loss: 16.4616 - val_mae: 2.6441
# Epoch 30/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.7124 - mae: 0.6021 - val_loss: 16.5432 - val_mae: 2.6173
# Epoch 31/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.7578 - mae: 0.6367 - val_loss: 17.2264 - val_mae: 2.7097
# Epoch 32/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.7433 - mae: 0.6127 - val_loss: 17.1089 - val_mae: 2.6748
# Epoch 33/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.7210 - mae: 0.5889 - val_loss: 16.2075 - val_mae: 2.6388
# Epoch 34/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6726 - mae: 0.5992 - val_loss: 19.3929 - val_mae: 2.9058
# Epoch 35/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.7568 - mae: 0.6216 - val_loss: 16.5952 - val_mae: 2.6108
# Epoch 36/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.7363 - mae: 0.6282 - val_loss: 16.4119 - val_mae: 2.6427
# Epoch 37/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6526 - mae: 0.5770 - val_loss: 16.9841 - val_mae: 2.7497
# Epoch 38/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.7114 - mae: 0.6098 - val_loss: 17.4873 - val_mae: 2.7235
# Epoch 39/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.7295 - mae: 0.6046 - val_loss: 15.9857 - val_mae: 2.5186
# Epoch 40/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.7212 - mae: 0.6110 - val_loss: 15.7933 - val_mae: 2.6767
# Epoch 41/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.6937 - mae: 0.5973 - val_loss: 15.9842 - val_mae: 2.5692
# Epoch 42/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.7099 - mae: 0.6135 - val_loss: 16.3132 - val_mae: 2.6080
# Epoch 43/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6458 - mae: 0.5818 - val_loss: 15.6596 - val_mae: 2.5850
# Epoch 44/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6777 - mae: 0.5788 - val_loss: 16.3252 - val_mae: 2.6544
# Epoch 45/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.7168 - mae: 0.5990 - val_loss: 15.5565 - val_mae: 2.5732
# Epoch 46/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.7965 - mae: 0.6142 - val_loss: 18.4154 - val_mae: 2.7978
# Epoch 47/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6280 - mae: 0.5589 - val_loss: 16.9863 - val_mae: 2.7160
# Epoch 48/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.7529 - mae: 0.6010 - val_loss: 18.5729 - val_mae: 2.8133
# Epoch 49/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6987 - mae: 0.5893 - val_loss: 16.7771 - val_mae: 2.7241
# Epoch 50/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.7623 - mae: 0.6097 - val_loss: 16.5806 - val_mae: 2.6738
# Epoch 51/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6748 - mae: 0.5952 - val_loss: 16.1765 - val_mae: 2.6636
# Epoch 52/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6553 - mae: 0.5618 - val_loss: 16.2097 - val_mae: 2.6365
# Epoch 53/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.6985 - mae: 0.5891 - val_loss: 15.8391 - val_mae: 2.6272
# Epoch 54/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6089 - mae: 0.5735 - val_loss: 17.4290 - val_mae: 2.7570
# Epoch 55/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.7317 - mae: 0.6049 - val_loss: 17.1004 - val_mae: 2.6986
# Epoch 56/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.7118 - mae: 0.5896 - val_loss: 16.9489 - val_mae: 2.6796
# Epoch 57/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6424 - mae: 0.5768 - val_loss: 16.7492 - val_mae: 2.6221
# Epoch 58/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.7136 - mae: 0.6047 - val_loss: 17.5678 - val_mae: 2.6873
# Epoch 59/100
# 51/51 [==============================] - 0s 6ms/step - loss: 0.6614 - mae: 0.5782 - val_loss: 17.7988 - val_mae: 2.7281
# Epoch 60/100
# 51/51 [==============================] - 0s 6ms/step - loss: 0.6691 - mae: 0.5781 - val_loss: 17.4448 - val_mae: 2.8278
# Epoch 61/100
# 51/51 [==============================] - 0s 6ms/step - loss: 0.6506 - mae: 0.5733 - val_loss: 16.1613 - val_mae: 2.5472
# Epoch 62/100
# 51/51 [==============================] - 0s 7ms/step - loss: 0.7074 - mae: 0.6057 - val_loss: 15.5877 - val_mae: 2.5976
# Epoch 63/100
# 51/51 [==============================] - 0s 6ms/step - loss: 0.6600 - mae: 0.5786 - val_loss: 16.7865 - val_mae: 2.7668
# Epoch 64/100
# 51/51 [==============================] - 0s 6ms/step - loss: 0.7388 - mae: 0.6104 - val_loss: 16.6147 - val_mae: 2.5721
# Epoch 65/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.6471 - mae: 0.5804 - val_loss: 16.3382 - val_mae: 2.6253
# Epoch 66/100
# 51/51 [==============================] - 0s 6ms/step - loss: 0.6782 - mae: 0.5929 - val_loss: 17.6070 - val_mae: 2.6962
# Epoch 67/100
# 51/51 [==============================] - 0s 6ms/step - loss: 0.6838 - mae: 0.5810 - val_loss: 16.1503 - val_mae: 2.5493
# Epoch 68/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.5738 - mae: 0.5420 - val_loss: 17.0323 - val_mae: 2.7095
# Epoch 69/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6892 - mae: 0.6268 - val_loss: 16.0057 - val_mae: 2.6210
# Epoch 70/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6853 - mae: 0.5694 - val_loss: 17.3210 - val_mae: 2.7157
# Epoch 71/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6696 - mae: 0.5965 - val_loss: 16.2719 - val_mae: 2.5655
# Epoch 72/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6615 - mae: 0.5731 - val_loss: 18.1977 - val_mae: 2.8338
# Epoch 73/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6926 - mae: 0.5805 - val_loss: 16.7189 - val_mae: 2.6381
# Epoch 74/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.7143 - mae: 0.5666 - val_loss: 15.8979 - val_mae: 2.5558
# Epoch 75/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6437 - mae: 0.5642 - val_loss: 15.6634 - val_mae: 2.6281
# Epoch 76/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6064 - mae: 0.5379 - val_loss: 17.1513 - val_mae: 2.6869
# Epoch 77/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.6021 - mae: 0.5623 - val_loss: 16.9568 - val_mae: 2.6685
# Epoch 78/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.7128 - mae: 0.6011 - val_loss: 17.4418 - val_mae: 2.6721
# Epoch 79/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6065 - mae: 0.5667 - val_loss: 15.8347 - val_mae: 2.5619
# Epoch 80/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.7273 - mae: 0.5912 - val_loss: 16.2535 - val_mae: 2.5936
# Epoch 81/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6566 - mae: 0.5808 - val_loss: 15.8127 - val_mae: 2.6507
# Epoch 82/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.5912 - mae: 0.5472 - val_loss: 17.0523 - val_mae: 2.7080
# Epoch 83/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6215 - mae: 0.5589 - val_loss: 16.5021 - val_mae: 2.6472
# Epoch 84/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.5977 - mae: 0.5696 - val_loss: 16.4618 - val_mae: 2.7066
# Epoch 85/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6681 - mae: 0.5530 - val_loss: 16.4187 - val_mae: 2.5830
# Epoch 86/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.5784 - mae: 0.5495 - val_loss: 17.0057 - val_mae: 2.7127
# Epoch 87/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.5997 - mae: 0.5618 - val_loss: 16.9293 - val_mae: 2.7115
# Epoch 88/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6229 - mae: 0.5558 - val_loss: 15.8575 - val_mae: 2.5197
# Epoch 89/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.5981 - mae: 0.5681 - val_loss: 16.1013 - val_mae: 2.5710
# Epoch 90/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.5923 - mae: 0.5586 - val_loss: 19.4092 - val_mae: 2.9569
# Epoch 91/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6951 - mae: 0.5666 - val_loss: 19.6243 - val_mae: 2.8659
# Epoch 92/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.6341 - mae: 0.5524 - val_loss: 16.2030 - val_mae: 2.6647
# Epoch 93/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6429 - mae: 0.5666 - val_loss: 16.0235 - val_mae: 2.5542
# Epoch 94/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.5885 - mae: 0.5515 - val_loss: 16.8173 - val_mae: 2.6856
# Epoch 95/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.6377 - mae: 0.5635 - val_loss: 16.6678 - val_mae: 2.6465
# Epoch 96/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.5575 - mae: 0.5212 - val_loss: 16.0172 - val_mae: 2.6775
# Epoch 97/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.7510 - mae: 0.6214 - val_loss: 18.9081 - val_mae: 2.8666
# Epoch 98/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.5821 - mae: 0.5284 - val_loss: 16.2714 - val_mae: 2.5851
# Epoch 99/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6551 - mae: 0.5601 - val_loss: 17.3602 - val_mae: 2.7033
# Epoch 100/100
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6792 - mae: 0.5723 - val_loss: 17.7068 - val_mae: 2.7009

# %%
# 모델 학습 히스토리에서 loss, val_loss, mae, val_mae를 차트로 보여줍니다.
plt.style.use('seaborn-white')

history_dict = history.history

loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b-', label='train_loss')
ax1.plot(epochs, val_loss, 'r-', label='val_loss')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

mae = history_dict['mae']
val_mae = history_dict['val_mae']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, mae, 'b-', label='train_mae')
ax2.plot(epochs, val_mae, 'r-', label='val_mae')
ax2.set_title('Train and Validation MAE')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()
# Out:
# <ipython-input-49-eee1a1311e5a>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')

# %%
# 문제 1-4: 테스트 데이터셋을 이용해 모델을 평가합니다.
model.evaluate(test_data, test_labels)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 17.7068 - mae: 2.7009
# [17.706762313842773, 2.700878143310547]
