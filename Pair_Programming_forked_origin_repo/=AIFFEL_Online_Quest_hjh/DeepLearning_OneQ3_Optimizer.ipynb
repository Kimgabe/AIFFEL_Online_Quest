# %% [markdown]
# <a href="https://colab.research.google.com/github/hjhan1201/AIFFEL_Online_Quest/blob/main/DeepLearning_OneQ3_Optimizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

X, y = make_regression(n_samples=200, n_features=1,
                       bias=5.0, noise=5.0, random_state=123)
y = np.expand_dims(y, axis=1)

plt.scatter(X, y)
plt.show()

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    shuffle=True,
                                                    random_state=123)

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (160, 1) (160, 1)
# (40, 1) (40, 1)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models, layers, optimizers, utils

# %%
model = keras.Sequential()
model.add(layers.Dense(1, activation='linear', input_shape=(1,)))
model.summary()
utils.plot_model(model)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
optimizer = optimizers.SGD()
model.compile(loss='mse', optimizer=optimizer, metrics=['mae', 'mse'])
history = model.fit(x_train, y_train, epochs=40)
# Out:
# Epoch 1/40
# 5/5 [==============================] - 1s 7ms/step - loss: 622.8146 - mae: 19.9709 - mse: 622.8146
# Epoch 2/40
# 5/5 [==============================] - 0s 4ms/step - loss: 500.1020 - mae: 17.9013 - mse: 500.1020
# Epoch 3/40
# 5/5 [==============================] - 0s 4ms/step - loss: 402.3936 - mae: 16.1523 - mse: 402.3936
# Epoch 4/40
# 5/5 [==============================] - 0s 4ms/step - loss: 324.6725 - mae: 14.4704 - mse: 324.6725
# Epoch 5/40
# 5/5 [==============================] - 0s 4ms/step - loss: 262.8178 - mae: 13.0540 - mse: 262.8178
# Epoch 6/40
# 5/5 [==============================] - 0s 3ms/step - loss: 213.7141 - mae: 11.7223 - mse: 213.7141
# Epoch 7/40
# 5/5 [==============================] - 0s 4ms/step - loss: 174.3054 - mae: 10.5690 - mse: 174.3054
# Epoch 8/40
# 5/5 [==============================] - 0s 4ms/step - loss: 143.1100 - mae: 9.5891 - mse: 143.1100
# Epoch 9/40
# 5/5 [==============================] - 0s 4ms/step - loss: 118.2696 - mae: 8.7325 - mse: 118.2696
# Epoch 10/40
# 5/5 [==============================] - 0s 4ms/step - loss: 98.4953 - mae: 7.9394 - mse: 98.4953
# Epoch 11/40
# 5/5 [==============================] - 0s 4ms/step - loss: 82.5060 - mae: 7.2759 - mse: 82.5060
# Epoch 12/40
# 5/5 [==============================] - 0s 4ms/step - loss: 69.9018 - mae: 6.6946 - mse: 69.9018
# Epoch 13/40
# 5/5 [==============================] - 0s 4ms/step - loss: 59.9203 - mae: 6.2309 - mse: 59.9203
# Epoch 14/40
# 5/5 [==============================] - 0s 5ms/step - loss: 51.9356 - mae: 5.7681 - mse: 51.9356
# Epoch 15/40
# 5/5 [==============================] - 0s 6ms/step - loss: 45.4773 - mae: 5.3950 - mse: 45.4773
# Epoch 16/40
# 5/5 [==============================] - 0s 5ms/step - loss: 40.4273 - mae: 5.0448 - mse: 40.4273
# Epoch 17/40
# 5/5 [==============================] - 0s 6ms/step - loss: 36.4169 - mae: 4.7894 - mse: 36.4169
# Epoch 18/40
# 5/5 [==============================] - 0s 6ms/step - loss: 33.1583 - mae: 4.5543 - mse: 33.1583
# Epoch 19/40
# 5/5 [==============================] - 0s 6ms/step - loss: 30.6188 - mae: 4.3541 - mse: 30.6188
# Epoch 20/40
# 5/5 [==============================] - 0s 5ms/step - loss: 28.6090 - mae: 4.1999 - mse: 28.6090
# Epoch 21/40
# 5/5 [==============================] - 0s 6ms/step - loss: 26.9770 - mae: 4.0596 - mse: 26.9770
# Epoch 22/40
# 5/5 [==============================] - 0s 4ms/step - loss: 25.6973 - mae: 3.9771 - mse: 25.6973
# Epoch 23/40
# 5/5 [==============================] - 0s 6ms/step - loss: 24.6803 - mae: 3.8966 - mse: 24.6803
# Epoch 24/40
# 5/5 [==============================] - 0s 6ms/step - loss: 23.8335 - mae: 3.8381 - mse: 23.8335
# Epoch 25/40
# 5/5 [==============================] - 0s 5ms/step - loss: 23.1727 - mae: 3.7890 - mse: 23.1727
# Epoch 26/40
# 5/5 [==============================] - 0s 7ms/step - loss: 22.6757 - mae: 3.7580 - mse: 22.6757
# Epoch 27/40
# 5/5 [==============================] - 0s 5ms/step - loss: 22.2469 - mae: 3.7243 - mse: 22.2469
# Epoch 28/40
# 5/5 [==============================] - 0s 6ms/step - loss: 21.9125 - mae: 3.7002 - mse: 21.9125
# Epoch 29/40
# 5/5 [==============================] - 0s 5ms/step - loss: 21.6533 - mae: 3.6797 - mse: 21.6533
# Epoch 30/40
# 5/5 [==============================] - 0s 5ms/step - loss: 21.4526 - mae: 3.6638 - mse: 21.4526
# Epoch 31/40
# 5/5 [==============================] - 0s 5ms/step - loss: 21.2611 - mae: 3.6534 - mse: 21.2611
# Epoch 32/40
# 5/5 [==============================] - 0s 5ms/step - loss: 21.1634 - mae: 3.6455 - mse: 21.1634
# Epoch 33/40
# 5/5 [==============================] - 0s 3ms/step - loss: 21.0382 - mae: 3.6337 - mse: 21.0382
# Epoch 34/40
# 5/5 [==============================] - 0s 4ms/step - loss: 20.9344 - mae: 3.6254 - mse: 20.9344
# Epoch 35/40
# 5/5 [==============================] - 0s 5ms/step - loss: 20.9060 - mae: 3.6223 - mse: 20.9060
# Epoch 36/40
# 5/5 [==============================] - 0s 4ms/step - loss: 20.8313 - mae: 3.6166 - mse: 20.8313
# Epoch 37/40
# 5/5 [==============================] - 0s 5ms/step - loss: 20.7792 - mae: 3.6109 - mse: 20.7792
# Epoch 38/40
# 5/5 [==============================] - 0s 4ms/step - loss: 20.7423 - mae: 3.6085 - mse: 20.7423
# Epoch 39/40
# 5/5 [==============================] - 0s 5ms/step - loss: 20.7560 - mae: 3.6050 - mse: 20.7560
# Epoch 40/40
# 5/5 [==============================] - 0s 3ms/step - loss: 20.7047 - mae: 3.6033 - mse: 20.7047

# %%
plt.plot(history.history['mae'])
plt.plot(history.history['mse'])
plt.xlabel('Epoch')
plt.legend(['mae', 'mse'])
plt.show();

# %%
model.evaluate(x_test, y_test)
# Out:
# 2/2 [==============================] - 0s 19ms/step - loss: 21.9299 - mae: 3.9887 - mse: 21.9299
# [21.929903030395508, 3.988684892654419, 21.929903030395508]

# %%
result = model.predict(X)

plt.scatter(X, y)
plt.plot(X, result, 'r')
plt.show()
# Out:
# 7/7 [==============================] - 0s 8ms/step

# %%
model.layers

# %%
layer = model.layers[0]
print(layer.name)
layer = model.get_layer('dense_1')
print(layer.name)
# Out:
# dense_1
# dense_1

# %%
weights, biases = layer.get_weights()
print(weights)
print(biases)
# Out:
# [[22.896503]]
# [4.1798525]

# %%
plt.scatter(X, y)
plt.plot(X, np.array(weights * X + biases), 'r')
plt.show()
