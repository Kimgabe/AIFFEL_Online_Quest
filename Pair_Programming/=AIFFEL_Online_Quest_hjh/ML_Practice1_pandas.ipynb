# %% [markdown]
# <a href="https://colab.research.google.com/github/hjhan1201/AIFFEL_Online_Quest/blob/main/ML_Practice1_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#라이브러리 불러오기
# Q. 판다스 라이브러리를 'pd'를 별칭으로 불러와주세요.
import pandas as pd

#데이터 프레임과 시리즈
# Q. 다음의 시리즈 menu, price를 합쳐서 데이터프레임을 만들어보세요.
menu = pd.Series(['후라이드', '양념치킨', '양반후반'], name="메뉴")
price = pd.Series([12000, 13000, 13000], name='가격')
pd.DataFrame({
    '메뉴' : menu,
    '가격' : price
})

 #데이터 불러오기 및 저장
 #Q. csv 파일을 저장한 변수의 type은 무엇일까요? 다음 df 변수의 타입을 확인해보세요.
data = {
    "메뉴":['후라이드', '양념치킨', '간장치킨', '마늘치킨', '파닭', '닭강정', '양반후반'],
    "가격":[12000, 13000, 14000, 14000, 14000, 15000, 13000],
    "호수":['10호', '10호', '9호', '9호', '11호', '12호', '10호'],
    "칼로리":[1000, 1400, 1600, 1800, 1300, 1500, 1300],
}
data = pd.DataFrame(data)
data.to_csv('modudak.csv', index=False)
#데이터 불러와서 변수에 담기
df = pd.read_csv('modudak.csv')
#데이터 샘플 확인 : 앞에서부터 n개(기본 5개)
df.head(3)
df.tail(2)
df.to_csv('test.csv',index=False)
pd.read_csv('test.csv')

#데이터 선택하기
#시리즈 선택(대괄호 하나)
df['메뉴']
df.메뉴
#데이터프레임 선택(대괄호 두개)
df[['메뉴','가격']]
#행(row) 선택
df['가격'] >=14000
cond = df['가격'] >=14000
df[cond]
#조건 2개 이상일때
cond1 = df['가격'] >=14000
cond2 = df['호수'] == '9호'
df[cond1|cond2]
#isin
cond3 = df['호수'].isin(['9호','10호'])
df[cond3]

#인덱싱/슬라이싱
df = pd.read_csv('modudak.csv')
#인덱스명 변경
df['index'] = ['a','b','c','d','e','f','g',]
df= df.set_index(keys=['index'])
#loc(인덱스명, 컬럼명)
df.loc['a']
df.loc[:,'가격']
df.loc['b','가격']
df.loc['c','메뉴':'칼로리']
df.loc['c',['메뉴','칼로리']]
df.loc['b':'d','메뉴':'가격']
#iloc(인덱스 번호, 컬럼 번호)
df.iloc[0]
df.iloc[:,1]
df.iloc[2,[0,1]]
df.iloc[2,0:2]
df.iloc[1:3]
df.iloc[1:3,0:3]

#index다루기
#set_index
df = df.set_index(keys=['메뉴'])
df.loc['양념치킨':'마늘치킨','호수':'칼로리']
df.iloc[1:4,1:]
#reset_index(기본값 drop=false) < 기존 인덱스를 컬럼으로 원복 시킨다. True의 경우, 기존 인덱스가 아예 사라짐
df = df.reset_index()
df

#행과 열 추가
#열 추가(column)
df['할인율'] = 0.2
#할인가
df['할인가'] = df['가격']*(1-df['할인율'])
#결측값으로 컬럼 추가(NaN)
import numpy as np
df['원산지'] = np.nan
aiffel = ['아이펠치킨',16000,'11호',1200, 0.5, 8000,'국내산']
df
df.loc['new'] = aiffel
#딕셔너리 형태로 추가
flip ={'메뉴':'풀잎치킨','가격':10000,'호수':'10호',}
df.loc[10] = flip

#값 변경
#후라이드 원산지 변경
df.loc[0,'원산지'] = '국내산'
df.iloc[4:6, 6] = '브라질'
df.iloc[6,0] = '양념반후라이드반'
df= df.replace('아이펠치킨','[인기]아이펠치킨').replace('풀잎치킨','[베스트] 풀잎치킨')
d = {'후라이드':'황금후라이드','양념치킨':'승일양념치킨'}
df=df.replace(d)
df=df.replace(10000,9900)
df.to_csv('new_modudak.csv')
df
# Out:
#              메뉴     가격   호수     칼로리  할인율      할인가  원산지
# 0        황금후라이드  12000  10호  1000.0  0.2   9600.0  국내산
# 1        승일양념치킨  13000  10호  1400.0  0.2  10400.0  NaN
# 2          간장치킨  14000   9호  1600.0  0.2  11200.0  NaN
# 3          마늘치킨  14000   9호  1800.0  0.2  11200.0  NaN
# 4            파닭  14000  11호  1300.0  0.2  11200.0  브라질
# 5           닭강정  15000  12호  1500.0  0.2  12000.0  브라질
# 6      양념반후라이드반  13000  10호  1300.0  0.2  10400.0  NaN
# new   [인기]아이펠치킨  16000  11호  1200.0  0.5   8000.0  국내산
# 10   [베스트] 풀잎치킨   9900  10호     NaN  NaN      NaN  NaN
