# %% [markdown]
# <a href="https://colab.research.google.com/github/hjhan1201/AIFFEL_Online_Quest/blob/main/DeepLearning_CV5_U_net.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install graphviz
# !pip install pydot
# Out:
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (0.20.1)
# Requirement already satisfied: pydot in /usr/local/lib/python3.10/dist-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from pydot) (3.1.1)

# %%
import tensorflow.keras.layers as layers
import tensorflow as tf

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
inputs = layers.Input(shape=(572, 572, 1))

# Contracting path 시작
# [1]
conv0 = layers.Conv2D(64, activation='relu', kernel_size = 3)(inputs)
conv1 = layers.Conv2D(64, activation='relu', kernel_size = 3)(conv0)  # Skip connection으로 Expanding path로 이어질 예정
conv2 = layers.MaxPool2D(pool_size=(2, 2), strides=(2, 2))(conv1)


# Q.위 이미지를 보고 [2]번 블럭을 구현해 봅시다. (filter 수를 주의하세요!)
conv3 = layers.Conv2D(128, activation='relu', kernel_size = 3)(conv2)
conv4 = layers.Conv2D(128, activation='relu', kernel_size = 3)(conv3)  # Skip connection으로 Expanding path로 이어질 예정
conv5 = layers.MaxPool2D(pool_size=(2, 2), strides=(2, 2))(conv4)


# Q.위 이미지를 보고 [3]번 블럭을 구현해 봅시다. (filter 수를 주의하세요!)
conv6 = layers.Conv2D(256, activation='relu', kernel_size = 3)(conv5)
conv7 = layers.Conv2D(256, activation='relu', kernel_size = 3)(conv6)  # Skip connection으로 Expanding path로 이어질 예정
conv8 = layers.MaxPool2D(pool_size=(2, 2), strides=(2, 2))(conv7)


# Q.위 이미지를 보고 [4]번 블럭을 구현해 봅시다. (filter 수를 주의하세요!)
conv9 = layers.Conv2D(512, activation='relu', kernel_size = 3)(conv8)
conv10 = layers.Conv2D(512, activation='relu', kernel_size = 3)(conv9)  # Skip connection으로 Expanding path로 이어질 예정
conv11 = layers.MaxPool2D(pool_size=(2, 2), strides=(2, 2))(conv10)


# [5]
conv12 = layers.Conv2D(1024, activation='relu', kernel_size=3)(conv11)
conv13 = layers.Conv2D(1024, activation='relu', kernel_size=3)(conv12)
# Contracting path 끝

# Expanding path 시작
# [6]
trans01 = layers.Conv2DTranspose(512, kernel_size=2, strides=(2, 2), activation='relu')(conv13)
crop01 = layers.Cropping2D(cropping=(4, 4))(conv10)
concat01 = layers.concatenate([trans01, crop01], axis=-1)

# [7]
conv14 = layers.Conv2D(512, activation='relu', kernel_size=3)(concat01)
conv15 = layers.Conv2D(512, activation='relu', kernel_size=3)(conv14)
trans02 = layers.Conv2DTranspose(256, kernel_size=2, strides=(2, 2), activation='relu')(conv15)

# [8]
crop02 = layers.Cropping2D(cropping=(16, 16))(conv7)
concat02 = layers.concatenate([trans02, crop02], axis=-1)


# Q.위 이미지를 보고 [9]번 블럭을 구현해 봅시다. (filter 수를 주의하세요!)
conv16 = layers.Conv2D(256, activation='relu', kernel_size=3)(concat02)
conv17 = layers.Conv2D(256, activation='relu', kernel_size=3)(conv16)
trans03 = layers.Conv2DTranspose(256, kernel_size=2, strides=(2, 2), activation='relu')(conv17)


# Q.위 이미지를 보고 [10]번 블럭을 구현해 봅시다. (cropping=(40, 40))
crop03 = layers.Cropping2D(cropping=(40, 40))(conv4)
concat03 = layers.concatenate([trans03, crop03], axis=-1)


# Q.위 이미지를 보고 [11]번 블럭을 구현해 봅시다. (filter 수를 주의하세요!)
conv18 = layers.Conv2D(128, activation='relu', kernel_size=3)(concat03)
conv19 = layers.Conv2D(128, activation='relu', kernel_size=3)(conv18)
trans04 = layers.Conv2DTranspose(128, kernel_size=2, strides=(2, 2), activation='relu')(conv19)


# Q.위 이미지를 보고 [12]번 블럭을 구현해 봅시다. (cropping=(88, 88))
crop04 = layers.Cropping2D(cropping=(88, 88))(conv1)
concat04 = layers.concatenate([trans04, crop04], axis=-1)


# [13]
conv20 = layers.Conv2D(64, activation='relu', kernel_size=3)(concat04)
conv21 = layers.Conv2D(64, activation='relu', kernel_size=3)(conv20)
# Expanding path 끝

outputs = layers.Conv2D(2, kernel_size=1)(conv21)

model = tf.keras.Model(inputs=inputs, outputs=outputs, name="u-netmodel")

# %%
model.summary()
# Out:
# Model: "u-netmodel"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_19 (InputLayer)       [(None, 572, 572, 1)]        0         []
#
#  conv2d_263 (Conv2D)         (None, 570, 570, 64)         640       ['input_19[0][0]']
#
#  conv2d_264 (Conv2D)         (None, 568, 568, 64)         36928     ['conv2d_263[0][0]']
#
#  max_pooling2d_72 (MaxPooli  (None, 284, 284, 64)         0         ['conv2d_264[0][0]']
#  ng2D)
#
#  conv2d_265 (Conv2D)         (None, 282, 282, 128)        73856     ['max_pooling2d_72[0][0]']
#
#  conv2d_266 (Conv2D)         (None, 280, 280, 128)        147584    ['conv2d_265[0][0]']
#
#  max_pooling2d_73 (MaxPooli  (None, 140, 140, 128)        0         ['conv2d_266[0][0]']
#  ng2D)
#
#  conv2d_267 (Conv2D)         (None, 138, 138, 256)        295168    ['max_pooling2d_73[0][0]']
#
#  conv2d_268 (Conv2D)         (None, 136, 136, 256)        590080    ['conv2d_267[0][0]']
#
#  max_pooling2d_74 (MaxPooli  (None, 68, 68, 256)          0         ['conv2d_268[0][0]']
#  ng2D)
#
#  conv2d_269 (Conv2D)         (None, 66, 66, 512)          1180160   ['max_pooling2d_74[0][0]']
#
#  conv2d_270 (Conv2D)         (None, 64, 64, 512)          2359808   ['conv2d_269[0][0]']
#
#  max_pooling2d_75 (MaxPooli  (None, 32, 32, 512)          0         ['conv2d_270[0][0]']
#  ng2D)
#
#  conv2d_271 (Conv2D)         (None, 30, 30, 1024)         4719616   ['max_pooling2d_75[0][0]']
#
#  conv2d_272 (Conv2D)         (None, 28, 28, 1024)         9438208   ['conv2d_271[0][0]']
#
#  conv2d_transpose_59 (Conv2  (None, 56, 56, 512)          2097664   ['conv2d_272[0][0]']
#  DTranspose)
#
#  cropping2d_59 (Cropping2D)  (None, 56, 56, 512)          0         ['conv2d_270[0][0]']
#
#  concatenate_47 (Concatenat  (None, 56, 56, 1024)         0         ['conv2d_transpose_59[0][0]',
#  e)                                                                  'cropping2d_59[0][0]']
#
#  conv2d_273 (Conv2D)         (None, 54, 54, 512)          4719104   ['concatenate_47[0][0]']
#
#  conv2d_274 (Conv2D)         (None, 52, 52, 512)          2359808   ['conv2d_273[0][0]']
#
#  conv2d_transpose_60 (Conv2  (None, 104, 104, 256)        524544    ['conv2d_274[0][0]']
#  DTranspose)
#
#  cropping2d_60 (Cropping2D)  (None, 104, 104, 256)        0         ['conv2d_268[0][0]']
#
#  concatenate_48 (Concatenat  (None, 104, 104, 512)        0         ['conv2d_transpose_60[0][0]',
#  e)                                                                  'cropping2d_60[0][0]']
#
#  conv2d_275 (Conv2D)         (None, 102, 102, 256)        1179904   ['concatenate_48[0][0]']
#
#  conv2d_276 (Conv2D)         (None, 100, 100, 256)        590080    ['conv2d_275[0][0]']
#
#  conv2d_transpose_61 (Conv2  (None, 200, 200, 256)        262400    ['conv2d_276[0][0]']
#  DTranspose)
#
#  cropping2d_61 (Cropping2D)  (None, 200, 200, 128)        0         ['conv2d_266[0][0]']
#
#  concatenate_49 (Concatenat  (None, 200, 200, 384)        0         ['conv2d_transpose_61[0][0]',
#  e)                                                                  'cropping2d_61[0][0]']
#
#  conv2d_277 (Conv2D)         (None, 198, 198, 128)        442496    ['concatenate_49[0][0]']
#
#  conv2d_278 (Conv2D)         (None, 196, 196, 128)        147584    ['conv2d_277[0][0]']
#
#  conv2d_transpose_62 (Conv2  (None, 392, 392, 128)        65664     ['conv2d_278[0][0]']
#  DTranspose)
#
#  cropping2d_62 (Cropping2D)  (None, 392, 392, 64)         0         ['conv2d_264[0][0]']
#
#  concatenate_50 (Concatenat  (None, 392, 392, 192)        0         ['conv2d_transpose_62[0][0]',
#  e)                                                                  'cropping2d_62[0][0]']
#
#  conv2d_279 (Conv2D)         (None, 390, 390, 64)         110656    ['concatenate_50[0][0]']
#
#  conv2d_280 (Conv2D)         (None, 388, 388, 64)         36928     ['conv2d_279[0][0]']
#
#  conv2d_281 (Conv2D)         (None, 388, 388, 2)          130       ['conv2d_280[0][0]']
#
# ==================================================================================================
# Total params: 31379010 (119.70 MB)
# Trainable params: 31379010 (119.70 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import model_to_dot
# !pip install tensorflow
from IPython.display import SVG
from tensorflow.keras.utils import model_to_dot

# %matplotlib inline

SVG(model_to_dot(model, show_shapes=True, show_layer_names=True, dpi=40).create(prog='dot', format='svg'))

# %% [markdown]
# Transposed Convolution을 코드로 살펴보기

# %%
# 필요한 모듈 불러오기
import numpy as np
import tensorflow as tf

# %%
# input data
X = np.asarray([[1, 2],
			  [3, 4]])

# %%
print(X)
print(X.shape)
# Out:
# [[1 2]
#  [3 4]]
# (2, 2)

# %%
# 모델에 맞게 reshaping
X = X.reshape((1, 2, 2, 1))

# %%
print(X)
print(X.shape)
# Out:
# [[[[1]
#    [2]]
#
#   [[3]
#    [4]]]]
# (1, 2, 2, 1)

# %%
# 모델 만들기
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv2DTranspose(1, (1, 1), strides=(2, 2), input_shape=(2, 2, 1))) # Conv2DTranspos layer

# %%
weights = [np.asarray([[[[5]]]]), np.asarray([1])] # weight = 1, bias = 1

# %%
weights
# Out:
# [array([[[[5]]]]), array([1])]

# %%
model.set_weights(weights)

# %%
yhat = model.predict(X)
yhat = yhat.reshape((4, 4)) # 결과를 확인하기 편하게 reshaping
print(yhat)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# [[ 6.  1. 11.  1.]
#  [ 1.  1.  1.  1.]
#  [16.  1. 21.  1.]
#  [ 1.  1.  1.  1.]]

# %%
# input data
X = np.asarray([[1, 2],
			  [3, 4]])
# 모델에 맞게 reshaping
X = X.reshape((1, 2, 2, 1))
# 모델 만들기
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv2DTranspose(1, (1, 1), strides=(2, 2), input_shape=(2, 2, 1))) # Conv2DTranspos layer
weights = [np.asarray([[[[1]]]]), np.asarray([1])] # weight = 1, bias = 1
model.set_weights(weights)
yhat = model.predict(X)
yhat = yhat.reshape((4, 4))
print(yhat)
# Out:
# 1/1 [==============================] - 0s 72ms/step
# [[2. 1. 3. 1.]
#  [1. 1. 1. 1.]
#  [4. 1. 5. 1.]
#  [1. 1. 1. 1.]]

# %%
# input data
X = np.asarray([[1, 2],
        [3, 4]])
# 모델에 맞게 reshaping
X = X.reshape((1, 2, 2, 1))
# 모델 만들기
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv2DTranspose(1, (2, 2), strides=(2, 2), input_shape=(2, 2, 1))) # Conv2DTranspos layer
weights = [np.asarray([[[[1, 1]]]]), np.asarray([1])] # weight = 1, bias = 1
model.set_weights(weights)
yhat = model.predict(X)
yhat = yhat.reshape((4, 4))
print(yhat)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-eb5295e4cadc> in <cell line: 10>()
#       8 model.add(tf.keras.layers.Conv2DTranspose(1, (2, 2), strides=(2, 2), input_shape=(2, 2, 1))) # Conv2DTranspos layer
#       9 weights = [np.asarray([[[[1, 1]]]]), np.asarray([1])] # weight = 1, bias = 1
# ---> 10 model.set_weights(weights)
#      11 yhat = model.predict(X)
#      12 yhat = yhat.reshape((4, 4))
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py in set_weights(self, weights)
#    1820                 ref_shape = param.shape
#    1821                 if not ref_shape.is_compatible_with(weight_shape):
# -> 1822                     raise ValueError(
#    1823                         f"Layer {self.name} weight shape {ref_shape} "
#    1824                         "is not compatible with provided weight "
#
# ValueError: Layer sequential_26 weight shape (2, 2, 1, 1) is not compatible with provided weight shape (1, 1, 1, 2).
